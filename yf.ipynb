# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2021, 1, 11)

# %%
df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  105158200.0
# 2021-01-11  130.169998  128.500000  129.190002  128.979996  100384500.0
#
#              Adj Close
# Date
# 2021-01-05  130.592697
# 2021-01-06  126.196747
# 2021-01-07  130.502991
# 2021-01-08  131.629379
# 2021-01-11  128.569168

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()
mavg
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04           NaN
# 2018-01-05           NaN
# 2018-01-08           NaN
#                  ...
# 2021-01-05    119.004585
# 2021-01-06    119.122090
# 2021-01-07    119.283678
# 2021-01-08    119.459515
# 2021-01-11    119.595246
# Name: Adj Close, Length: 762, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
rets = close_px / close_px.shift(1) - 1
rets.plot(label='return')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from yahoo_fin import stock_info as si

# %%
si.get_live_price("BTC-CAD")
# Out:
# 48196.87890625
